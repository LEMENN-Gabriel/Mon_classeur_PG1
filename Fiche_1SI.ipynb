# %% [markdown]
# ## Enseignement de spécialité Sciences de l'Ingénieur

# %% [markdown]
# ### Identification :
#
# - Nom : LE MENN
# - Prenom : Gabriel
# - Classe : PG 1
#
# ### Ce que je faisais en 2025-2026 ? Quoi ? Où ?
#
# J’étais élève de seconde au lycée Notre Dame du Mur, avec option section euro et accompagnement personalisé S.I
#
#
# ### Quelles sont mes autres spécialités ?
#
# - Mathématique
# - Physique-chimie
#
# ### Quel est mon projet d'orientation ? Dans quel domaine ? Vers quel métier ?
#
# Je vais sans doute me diriger vers une prepa, pour ensuite me diriger dans le domaine de l'aéronotique, avec l'objectif de devenir pilote de ligne.
#
# ##### 2 parcours que j'envisage après la prepa :
#
# - l'ENAC
# - Les cadets Air France
#
# ### Pourquoi j'ai choisi la spécialité Sciences de l'Ingénieur ? Qu'est-ce que j'en attends ?
#
# C'est une spécialité qui mélange les maths et la physique, ce sont 2 matières que j'apprécie.
# Je pense que c'est une spécialité qui me sera utile à l'avenir.

# %% [markdown]
# > Ce document est un [jupyter notebook](https://ericecmorlaix.github.io/adn-Tutoriel_lab_si/IDE/notebook/#exemples)
# > ![Illustration notebook jupyter](https://ericecmorlaix.github.io/img/JupyterNoteBook.png)
# > Vous pouvez télécharger ce fichier avec son extension `.ipynb` en cliquant dans le menu sur `Fichier>Enregistrer sous...` afin de l'éditer ensuite sur votre iPad en local avec l'application [Carnets](https://holzschu.github.io/Carnets_Jupyter/) ou dans votre navigateur avec [Basthon](https://notebook.basthon.fr/) comme sur [Capytale](https://capytale2.ac-paris.fr), ou encore avec [Visual Studio Code pour le Web](https://vscode.dev) en y installant les [extensions nécessaires](https://ericecmorlaix.github.io/adn-Tutoriel_lab_si/IDE/VSCode/#extensions-pour-vscode)...
